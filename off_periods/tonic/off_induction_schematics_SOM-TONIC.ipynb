# %%
mua = acr.mua.load_concat_peaks_df(subject, exp)
mua = mua.sort('datetime')
lfp = acr.io.load_concat_raw_data(subject, ['swi-bl', 'swi'])

# %%
#-------------------------- Standard Imports --------------------------#
# %reload_ext autoreload
# %autoreload 2
import kdephys as kde
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import acr
import xarray as xr
from scipy import stats
# ---------------------------- EXTRAS --------------------------------#
from kdephys.plot.main import _title, bp_plot
import kdephys.utils.spectral as sp
bands = sp.bands

import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
from acr.utils import *
pu = acr.utils.import_publication_functions('/home/kdriessen/gh_master/PUBLICATION__ACR/pub_utils.py', 'pu')
dag = acr.utils.import_publication_functions('/home/kdriessen/gh_master/PUBLICATION__ACR/data_agg.py', 'dag')

# %%
subject = 'ACR_40'
exp = 'swisin'

# %%
mua = acr.mua.load_concat_peaks_df(subject, exp)
pon, poff = acr.stim.get_individual_pulse_times(subject, exp)
emg = acr.io.load_concat_raw_data(subject, ['swisin'], stores=['EMGr'])
fp = acr.io.load_concat_raw_data(subject, ['swisin'])
h = acr.io.load_hypno_full_exp(subject, exp)
hd = acr.hypnogram_utils.create_acr_hyp_dict(subject, exp)
oodf = dag.compute_hybrid_off_df(subject, exp, chan_threshold=12)
oodf = acr.oo_utils.enhance_oodf(oodf, h, hd)

# %%
plt.rcdefaults()
acr.plots.lrg()
for pulse in np.arange(0, 5):
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=6)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXo').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXo').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXo')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat.to_pandas(), lfp_times)
    
    for a in ax:
        a.axvspan(t1 + pd.Timedelta(seconds=3), t1 + pd.Timedelta(seconds=6), color='blue', alpha=0.2)
    
    ax = kde.plot.main.shade_oodf(ax, oodf.prb('NNXo').oots(t1, t2))
    f.suptitle(f'Pulse {pulse}')

# %%
for subject in ['ACR_39', 'ACR_40', 'ACR_41', 'ACR_44']:
    exp = acr.utils.sub_swisin_exps[subject][0]
    mua = acr.mua.load_concat_peaks_df(subject, exp)
    pon, poff = acr.stim.get_individual_pulse_times(subject, exp)
    emg = acr.io.load_concat_raw_data(subject, [exp], stores=['EMGr'])
    fp = acr.io.load_concat_raw_data(subject, [exp])
    h = acr.io.load_hypno_full_exp(subject, exp)
    hd = acr.hypnogram_utils.create_acr_hyp_dict(subject, exp)
    oodf = dag.compute_hybrid_off_df(subject, exp, chan_threshold=12)
    oodf = acr.oo_utils.enhance_oodf(oodf, h, hd)
    plt.rcdefaults()
    acr.plots.lrg()
    for pulse in np.arange(0, 20):
        t1 = pon[pulse] - pd.Timedelta('3s')
        t2 = t1 + pd.Timedelta(seconds=6)
        # plot the optrode:
        lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXo').data.T
        lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXo').datetime.values
        mua_dat = mua.ts(t1, t2).prb('NNXo')
        f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat.to_pandas(), lfp_times)
        
        for a in ax:
            a.axvspan(t1 + pd.Timedelta(seconds=3), t1 + pd.Timedelta(seconds=6), color='blue', alpha=0.2)
        
        ax = kde.plot.main.shade_oodf(ax, oodf.prb('NNXo').oots(t1, t2))
        f.suptitle(f'Pulse {pulse}')
        plt.show()

# %%
for subject in ['ACR_25']:
    exp = acr.utils.sub_swisin_exps[subject][0]
    mua = acr.mua.load_concat_peaks_df(subject, exp)
    pon, poff = acr.stim.get_individual_pulse_times(subject, exp)
    emg = acr.io.load_concat_raw_data(subject, [exp], stores=['EMGr'])
    fp = acr.io.load_concat_raw_data(subject, [exp])
    h = acr.io.load_hypno_full_exp(subject, exp)
    hd = acr.hypnogram_utils.create_acr_hyp_dict(subject, exp)
    oodf = dag.compute_hybrid_off_df(subject, exp, chan_threshold=12)
    oodf = acr.oo_utils.enhance_oodf(oodf, h, hd)
    plt.rcdefaults()
    acr.plots.lrg()
    for pulse in np.arange(0, 20):
        t1 = pon[pulse] - pd.Timedelta('3s')
        t2 = t1 + pd.Timedelta(seconds=6)
        # plot the optrode:
        lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXo').data.T
        lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXo').datetime.values
        mua_dat = mua.ts(t1, t2).prb('NNXo')
        f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat.to_pandas(), lfp_times)
        
        for a in ax:
            a.axvspan(t1 + pd.Timedelta(seconds=3), t1 + pd.Timedelta(seconds=6), color='blue', alpha=0.2)
        
        ax = kde.plot.main.shade_oodf(ax, oodf.prb('NNXo').oots(t1, t2))
        f.suptitle(f'Pulse {pulse}')
        plt.show()

# %% [markdown]
# # Production Plots - ACR_40

# %%
nb_fig_root = f'{acr.utils.PAPER_FIGURE_ROOT}/schems/tonic_inhib_schems'

# %%
subject = 'ACR_40'
exp = acr.utils.sub_swisin_exps[subject][0]
mua = acr.mua.load_concat_peaks_df(subject, exp)
pon, poff = acr.stim.get_individual_pulse_times(subject, exp)
emg = acr.io.load_concat_raw_data(subject, [exp], stores=['EMGr'])
fp = acr.io.load_concat_raw_data(subject, [exp])
h = acr.io.load_hypno_full_exp(subject, exp)
hd = acr.hypnogram_utils.create_acr_hyp_dict(subject, exp)
oodf = dag.compute_hybrid_off_df(subject, exp, chan_threshold=12)
oodf = acr.oo_utils.enhance_oodf(oodf, h, hd)
plt.rcdefaults()
acr.plots.lrg()

# %%
pulse_to_start = 4
FSIZE = (16, 6)
mua_height_multiplier = 0.2
lw = 2.5
rsz = 30
seconds = 6

# %%
fig_name = f'{subject}__tonic-SCHEM_OPTRODE.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXo').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXo').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXo')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat, lfp_times, lfp_subplot_hspace=-0.25, lfp_color=SOM_BLUE, mua_color=SOM_BLUE, figsize=FSIZE, mua_height_multiplier=mua_height_multiplier, lw=lw, rsz=rsz)
    xticks = [pd.Timestamp(lfp_times.min()) + pd.Timedelta(seconds=i) for i in range(seconds+1)]
    ax[16].set_xticklabels([])
    ax[16].set_xticks(xticks)
    for i, a in enumerate(ax):
        if i != 16:
            print(a.get_ylim())
            a.set_ylim(-1200, 1000)
f.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')

# %%
fig_name = f'{subject}__tonic-SCHEM_OPTRODE--scalebar-offs.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXo').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXo').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXo')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat, lfp_times, lfp_subplot_hspace=-0.25, lfp_color=SOM_BLUE, mua_color=SOM_BLUE, figsize=FSIZE, mua_height_multiplier=mua_height_multiplier, lw=lw, rsz=rsz)
    xticks = [pd.Timestamp(lfp_times.min()) + pd.Timedelta(seconds=i) for i in range(seconds+1)]
    ax[16].set_xticklabels([])
    ax[16].set_xticks(xticks)
    for i, a in enumerate(ax):
        if i != 16:
            print(a.get_ylim())
            a.set_ylim(-1200, 1000)
ax[8].vlines(xticks[1], -1000, 1000, color='green', alpha=0.8, linewidth=8)
axm = kde.plot.main.shade_oodf(ax[16], oodf.prb('NNXo').oots(t1, t2), off_color='red', lw=0, alpha=0.3, single_ax=True)
f.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')

# %%
fig_name = f'{subject}__tonic-SCHEM_CONTRA.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXr').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXr').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXr')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat, lfp_times, lfp_subplot_hspace=-0.25, lfp_color=NNXR_GRAY, mua_color=NNXR_GRAY, figsize=FSIZE, mua_height_multiplier=mua_height_multiplier, lw=lw, rsz=rsz)
    xticks = [pd.Timestamp(lfp_times.min()) + pd.Timedelta(seconds=i) for i in range(seconds+1)]
    ax[16].set_xticklabels([])
    ax[16].set_xticks(xticks)
    for i, a in enumerate(ax):
        if i != 16:
            print(a.get_ylim())
            a.set_ylim(-1200, 1000)
f.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')

# %%
fig_name = f'{subject}__tonic-SCHEM_CONTRA--scalebar-offs.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXr').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXr').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXr')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat, lfp_times, lfp_subplot_hspace=-0.25, lfp_color=NNXR_GRAY, mua_color=NNXR_GRAY, figsize=FSIZE, mua_height_multiplier=mua_height_multiplier, lw=lw, rsz=rsz)
    xticks = [pd.Timestamp(lfp_times.min()) + pd.Timedelta(seconds=i) for i in range(seconds+1)]
    ax[16].set_xticklabels([])
    ax[16].set_xticks(xticks)
    for i, a in enumerate(ax):
        if i != 16:
            print(a.get_ylim())
            a.set_ylim(-1200, 1000)
ax[8].vlines(xticks[1], -1000, 1000, color='green', alpha=0.8, linewidth=8)
axm = kde.plot.main.shade_oodf(ax[16], oodf.prb('NNXr').oots(t1, t2), off_color='red', lw=0, alpha=0.3, single_ax=True)
f.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')

# %%
fig_name = f'{subject}__swi__OFF_INDUCTION_SCHEMATIC--EMG.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
plt.rcParams['axes.spines.left'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['ytick.left'] = False
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    fmg, axmg = plt.subplots(1, 1, figsize=(18, 1.5))
    axmg.plot(emg.prb('EMGr').sel(datetime=slice(t1, t2)).ch(1).datetime, emg.prb('EMGr').sel(datetime=slice(t1, t2)).ch(1).data, color=EMG_SLATE, linewidth=4.5)
    axmg.set_xlim(t1, t2)
    axmg.set_xticks(xticks)

fmg.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')
axmg.get_ylim()
axmg.set_ylim(-800, 1000)

# %%
subject = 'ACR_39'
exp = acr.utils.sub_swisin_exps[subject][0]
mua = acr.mua.load_concat_peaks_df(subject, exp)
pon, poff = acr.stim.get_individual_pulse_times(subject, exp)
emg = acr.io.load_concat_raw_data(subject, [exp], stores=['EMGr'])
fp = acr.io.load_concat_raw_data(subject, [exp])
h = acr.io.load_hypno_full_exp(subject, exp)
hd = acr.hypnogram_utils.create_acr_hyp_dict(subject, exp)
oodf = dag.compute_hybrid_off_df(subject, exp, chan_threshold=12)
oodf = acr.oo_utils.enhance_oodf(oodf, h, hd)
plt.rcdefaults()
acr.plots.lrg()

# %%
pulse_to_start = 3
FSIZE = (16, 6)
mua_height_multiplier = 0.2
lw = 2.5
rsz = 30
seconds = 6

# %%
fig_name = f'{subject}__tonic-SCHEM_OPTRODE.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXo').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXo').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXo')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat, lfp_times, lfp_subplot_hspace=-0.25, lfp_color=SOM_BLUE, mua_color=SOM_BLUE, figsize=FSIZE, mua_height_multiplier=mua_height_multiplier, lw=lw, rsz=rsz)
    xticks = [pd.Timestamp(lfp_times.min()) + pd.Timedelta(seconds=i) for i in range(seconds+1)]
    ax[16].set_xticklabels([])
    ax[16].set_xticks(xticks)
    for i, a in enumerate(ax):
        if i != 16:
            print(a.get_ylim())
            a.set_ylim(-550, 650)
f.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')

# %%
fig_name = f'{subject}__tonic-SCHEM_OPTRODE--scalebar-offs.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXo').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXo').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXo')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat, lfp_times, lfp_subplot_hspace=-0.25, lfp_color=SOM_BLUE, mua_color=SOM_BLUE, figsize=FSIZE, mua_height_multiplier=mua_height_multiplier, lw=lw, rsz=rsz)
    xticks = [pd.Timestamp(lfp_times.min()) + pd.Timedelta(seconds=i) for i in range(seconds+1)]
    ax[16].set_xticklabels([])
    ax[16].set_xticks(xticks)
    for i, a in enumerate(ax):
        if i != 16:
            print(a.get_ylim())
            a.set_ylim(-550, 650)
ax[8].vlines(xticks[1], -500, 500, color='green', alpha=0.8, linewidth=8)
axm = kde.plot.main.shade_oodf(ax[16], oodf.prb('NNXo').oots(t1, t2), off_color='red', lw=0, alpha=0.3, single_ax=True)
f.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')

# %%
fig_name = f'{subject}__tonic-SCHEM_CONTRA.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXr').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXr').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXr')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat, lfp_times, lfp_subplot_hspace=-0.25, lfp_color=NNXR_GRAY, mua_color=NNXR_GRAY, figsize=FSIZE, mua_height_multiplier=mua_height_multiplier, lw=lw, rsz=rsz)
    xticks = [pd.Timestamp(lfp_times.min()) + pd.Timedelta(seconds=i) for i in range(seconds+1)]
    ax[16].set_xticklabels([])
    ax[16].set_xticks(xticks)
    for i, a in enumerate(ax):
        if i != 16:
            print(a.get_ylim())
            a.set_ylim(-550, 650)
f.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')

# %%
fig_name = f'{subject}__tonic-SCHEM_CONTRA--scalebar-offs.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    # plot the optrode:
    lfp_dat = fp.sel(datetime=slice(t1, t2)).prb('NNXr').data.T
    lfp_times = fp.sel(datetime=slice(t1, t2)).prb('NNXr').datetime.values
    mua_dat = mua.ts(t1, t2).prb('NNXr')
    f, ax = kde.plot.main.plot_lfp_mua_combined(lfp_dat, mua_dat, lfp_times, lfp_subplot_hspace=-0.25, lfp_color=NNXR_GRAY, mua_color=NNXR_GRAY, figsize=FSIZE, mua_height_multiplier=mua_height_multiplier, lw=lw, rsz=rsz)
    xticks = [pd.Timestamp(lfp_times.min()) + pd.Timedelta(seconds=i) for i in range(seconds+1)]
    ax[16].set_xticklabels([])
    ax[16].set_xticks(xticks)
    for i, a in enumerate(ax):
        if i != 16:
            print(a.get_ylim())
            a.set_ylim(-550, 650)
ax[8].vlines(xticks[1], -500, 500, color='green', alpha=0.8, linewidth=8)
axm = kde.plot.main.shade_oodf(ax[16], oodf.prb('NNXr').oots(t1, t2), off_color='red', lw=0, alpha=0.3, single_ax=True)
f.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')

# %%
fig_name = f'{subject}__swi__OFF_INDUCTION_SCHEMATIC--EMG.png'
plt.rcdefaults()
acr.plots.lrg()
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.major.size'] = 14
plt.rcParams['axes.spines.left'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['ytick.left'] = False
for pulse in [pulse_to_start]:
    t1 = pon[pulse] - pd.Timedelta('3s')
    t2 = t1 + pd.Timedelta(seconds=seconds)
    fmg, axmg = plt.subplots(1, 1, figsize=(18, 1.5))
    axmg.plot(emg.prb('EMGr').sel(datetime=slice(t1, t2)).ch(1).datetime, emg.prb('EMGr').sel(datetime=slice(t1, t2)).ch(1).data, color=EMG_SLATE, linewidth=4.5)
    axmg.set_xlim(t1, t2)
    axmg.set_xticks(xticks)

print(axmg.get_ylim())
axmg.set_ylim(-360, 420)
fmg.savefig(f'{nb_fig_root}/{fig_name}', dpi=600, transparent=True, bbox_inches='tight')
